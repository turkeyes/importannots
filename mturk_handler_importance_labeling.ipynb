# %% [markdown]
# # Setup

# %%
# path to the config file (see example). 
# will work with a config file for https://github.com/kimberli/mturk-template, 
# but a minimal example is included.
# Also supports an additional feature, the "variants" key, which is a list of dictionaries. 
# If "variants" is specified, for each dictionary it contains, those keys will be meshed with the "hitCreation"
# key and one task will be made per variant. Else, config["hitCreation"]["numTasks"] versions of the same
# task will be launched. 
CONFIG_PATH = "./config.json"

# where to save downloaded results 
SAVE_PATH = "./result.csv" 

# Whether to launch a hit per fold.txt in folder "files"
LAUNCH_HITS_FOR_ALL_FOLDS = True
FOLD_REQ_STR = 'poster_clean'

# %% [markdown]
# ## Define folds to use in the hit
# The folds are txt files containing paths to the images to be used in the hit. This notebooks allows for creation of multiple hits, each with a different fold.txt .
# In the folder "files", multiple txt files (folds) can be found. Each one contains 10 images, and there are no repeats among folds. Each fold has a piece of the full canva_scraping2 dataset.

# %%
from boto3 import client
import json
import copy
import os

_USING_PROD = None

with open(CONFIG_PATH, 'r') as f:
    config = json.loads(f.read())
    hit_config = config['hitCreation']

if hit_config['production']:
    print("USING PROD")
    _USING_PROD = True
    endpoint_url = 'https://mturk-requester.us-east-1.amazonaws.com'
else:
    print("USING SANDBOX")
    _USING_PROD = False
    endpoint_url = 'https://mturk-requester-sandbox.us-east-1.amazonaws.com'
        
cl = client('mturk', region_name='us-east-1', endpoint_url=endpoint_url)

fld = None

if hit_config['fold']:
    hit_config['taskUrl'] = hit_config['taskUrl'] + "?url=%s" % hit_config['fold']
elif fld:
    hit_config['taskUrl'] = fld
else:
    fld = input('Define fold (input name+.txt)')
    hit_config['taskUrl'] = hit_config['taskUrl'] + "?url=%s" % fld

if LAUNCH_HITS_FOR_ALL_FOLDS:
    all_folds = [f for f in os.listdir('./files') if FOLD_REQ_STR in f]        
    print('Using folds:',all_folds)
    
print("TASK URL:", hit_config['taskUrl'])
# Out:
# USING SANDBOX
# Using folds: ['fold_poster_clean0.txt', 'fold_poster_clean1.txt', 'fold_poster_clean10.txt', 'fold_poster_clean11.txt', 'fold_poster_clean12.txt', 'fold_poster_clean13.txt', 'fold_poster_clean14.txt', 'fold_poster_clean2.txt', 'fold_poster_clean3.txt', 'fold_poster_clean4.txt', 'fold_poster_clean5.txt', 'fold_poster_clean6.txt', 'fold_poster_clean7.txt', 'fold_poster_clean8.txt', 'fold_poster_clean9.txt']
# TASK URL: https://cfosco.github.io/mturk-importance/?url=fold_info_notext.txt

# %% [markdown]
# # Make new HIT

# %%
# Safety flags that prevent you from accidentally messing up your HITs. 
# Set to False except when you are performing these specific tasks. 
ALLOW_HIT_CREATION = True
ALLOW_ASSIGNMENT_ADDITION = False
ALLOW_CREATE_QUAL = False
ALLOW_UPDATE_EXPIRATION = False

# %%
# List of qualifications that you will use to filter potential workers. 
# These require that workers come from the US and have an approval rating >= 95%
QUALS = [
       {
           'QualificationTypeId': '00000000000000000071',
           'Comparator': 'EqualTo',
           'LocaleValues': [{
               'Country': 'US',
           }],
       },
        
       {
           'QualificationTypeId': '000000000000000000L0',
           'Comparator': 'GreaterThanOrEqualTo',
           'IntegerValues': [
               95
           ],
       },
    ]

# %%
# creates a HIT in the form of an External Question inside an iFrame
def create_hit(task):
    questionText = "<ExternalQuestion xmlns=\"http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/"
    questionText += "2006-07-14/ExternalQuestion.xsd\">\n<ExternalURL>" + task['taskUrl']
    questionText += "</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>"

    response = cl.create_hit(
        MaxAssignments=task['numAssignments'],
        AutoApprovalDelayInSeconds=604800,
        LifetimeInSeconds=task['lifetime'],
        AssignmentDurationInSeconds=task['duration'],
        Reward=task['rewardAmount'],
        Title=task['title'],
        Keywords=task['keywords'],
        Description=task['description'],
        Question=questionText,
        QualificationRequirements=QUALS,
    )

    print(response)
    print("\n")

# %%
if ALLOW_HIT_CREATION: 
    if config.get('variants', None): 
        print("creating " + str(len(config['variants'])) + " variants")
        for var in config['variants']: 
            task = copy.deepcopy(config)
            task.update(var)
            create_hit(task)
    
    elif LAUNCH_HITS_FOR_ALL_FOLDS:
        print("creating", len(all_folds), "tasks")
        for fold in all_folds:
            hit_config['taskUrl'] = hit_config['taskUrl'].split('?')[0] + "?url=%s" % fold
            create_hit(hit_config)
    else:
        print("creating " + str(hit_config['numTasks']) + " tasks")
        for i in range(hit_config['numTasks']):
            create_hit(hit_config)
# Out:
# creating 15 tasks
# {'HIT': {'HITId': '31ODACBENUOB8UZ3X8IMTF6JGLDQS8', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 42, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean0.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 22, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '1e50eb26-7af9-43c5-ba36-8fbd6dd38665', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1e50eb26-7af9-43c5-ba36-8fbd6dd38665', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:42 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '37SQU136V7XNX6GSZADNWDB2I99115', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 42, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean1.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 22, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '2bca9e23-04bf-470f-963b-0ba1a22a8ca7', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '2bca9e23-04bf-470f-963b-0ba1a22a8ca7', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:42 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3XJOUITW8U0CNUCIM8NC3K25I4RQTX', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 42, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean10.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 22, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'ea85522b-7b40-49ba-aa52-f2de9585f382', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'ea85522b-7b40-49ba-aa52-f2de9585f382', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1412', 'date': 'Fri, 15 Feb 2019 04:19:42 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3K3IX1W4S60M8MCUGVH68AM3PJKPAK', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 42, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean11.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 22, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'dd366bdd-8a46-4c91-bfda-838a6be0799d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'dd366bdd-8a46-4c91-bfda-838a6be0799d', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1412', 'date': 'Fri, 15 Feb 2019 04:19:42 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3HEADTGN2P1RCNV74ICR9S0VBB9VRJ', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 43, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean12.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 23, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '9139a13a-65b0-4331-a95b-21b4527731f6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '9139a13a-65b0-4331-a95b-21b4527731f6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1412', 'date': 'Fri, 15 Feb 2019 04:19:42 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3SU800BH861RN7R7MDDM8GO71IYQUO', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 43, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean13.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 23, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '0da3b29d-34e4-421d-9785-49234a9f5bb5', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '0da3b29d-34e4-421d-9785-49234a9f5bb5', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1412', 'date': 'Fri, 15 Feb 2019 04:19:42 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3KA7IJSNW6ERRWHMM9H23L69715PBF', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 52, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean14.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 32, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '347937d5-9f74-44f9-b3b4-22fa0bd686a2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '347937d5-9f74-44f9-b3b4-22fa0bd686a2', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1412', 'date': 'Fri, 15 Feb 2019 04:19:52 GMT'}, 'RetryAttempts': 4}}
#
#
# {'HIT': {'HITId': '30EV7DWJTV4FUYSSH5WD5WDTX5XY6X', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 52, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean2.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 32, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '7fcbcc91-0ae9-42a6-8c4c-4b8a4511683d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '7fcbcc91-0ae9-42a6-8c4c-4b8a4511683d', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:52 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3WPCIUYH1AHIYL8DHMHS3LV6ZP2TDV', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 52, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean3.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 32, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'e7eb70fc-051f-45c2-97ca-5ccd59de6dc4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'e7eb70fc-051f-45c2-97ca-5ccd59de6dc4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:52 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '33EEIIWHK7GR0MG7R3NR42QQFP7QVD', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 52, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean4.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 32, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '991e1596-f6cd-4f3a-b2fe-e9025081a1c6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '991e1596-f6cd-4f3a-b2fe-e9025081a1c6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:52 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3TCFMTM8HEXUMRYOIED11WL7AFN12M', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 52, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean5.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 32, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'bb82c5b4-ef99-4c7c-ac39-7de92711a8c3', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'bb82c5b4-ef99-4c7c-ac39-7de92711a8c3', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:52 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3HA5ODM5KA13D2VKJ7CWZ25RXDSVS7', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 52, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean6.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 32, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '9735dce2-ed40-4227-b63b-621383ed7714', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '9735dce2-ed40-4227-b63b-621383ed7714', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:52 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3JGHED38ED0YYY6X0F15BADPSGHY7W', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 53, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean7.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 33, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '12d35764-5ad7-45fc-ac6e-c536ca939fa0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '12d35764-5ad7-45fc-ac6e-c536ca939fa0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:53 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3D5G8J4N5AD4S28Z87HM971DZW6VTW', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 53, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean8.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 33, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'c5f52901-0e70-49fc-a7f6-f62b5df89b4f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c5f52901-0e70-49fc-a7f6-f62b5df89b4f', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:53 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3NKW03WTLMG4FBGCHDSNQ494MY9QWN', 'HITTypeId': '3WSO80OI82F154PY9UKPZ6KAJ8U4LF', 'HITGroupId': '3PLXPMD6WGMSL5IISNN4IN6WGJNKBX', 'CreationTime': datetime.datetime(2019, 2, 14, 23, 19, 53, tzinfo=tzlocal()), 'Title': 'Annotate the most important regions on graphic designs', 'Description': 'Manually highlight the important parts of a graphic design. You will be shown a set of 10 images, and you will have to indicate which parts feel important to you.', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://cfosco.github.io/mturk-importance/?url=fold_poster_clean9.txt</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'labeling, importance, highlighting, graphic, designs, images', 'HITStatus': 'Assignable', 'MaxAssignments': 10, 'Reward': '0.90', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 2, 17, 3, 6, 33, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 10, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '27e658ae-994a-4c94-9197-b437ab5f4315', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '27e658ae-994a-4c94-9197-b437ab5f4315', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1411', 'date': 'Fri, 15 Feb 2019 04:19:53 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# # HIT monitoring helpers

# %%
MAX_RESULTS = 9 # set equal to the number of outstanding hits you have 

hits = cl.list_hits(MaxResults=MAX_RESULTS)['HITs']

# %%
print(len(hits))
# Out:
# 9

# %%
# Gets all assignments created for a HIT
def get_all_assignments(hitid): 
    assignments = []
    should_continue = True
    next_token = False
    while (should_continue): 
        args = {
            'HITId': hitid, 
            'MaxResults': 100
        }
        if (next_token): 
            args['NextToken'] = next_token
        r = cl.list_assignments_for_hit(**args)
        next_token = r.get('NextToken', False)
        assignments.extend(r["Assignments"])
        should_continue = len(r["Assignments"]) > 0
    return assignments

# %%
import datetime

# Summarizes all hits in `hits` in a human-readable way 
def summarize_hits(hits): 
    print(len(hits))
    ret = ""
    for hit in hits: 
        expiration = hit['Expiration'].replace(tzinfo=None)
        is_expired = expiration < datetime.datetime.now()
        description = ("Title: {title}\n" 
        "ID: {hid}\n"
        "\tAssignments left: {left}\n"
        "\tAssignments completed: {complete}\n"
        "\tAssignments pending: {pending}\n"
        "\tExpired: {exp}\n\n").format(
            title=hit['Title'], 
            hid=hit['HITId'], 
            left=hit['NumberOfAssignmentsAvailable'], 
            complete=hit['NumberOfAssignmentsCompleted'], 
            pending=hit['NumberOfAssignmentsPending'],
            exp=str(is_expired)
        )
        ret += description
    print(ret)

# %%
# Summarizes all pending/submitted/approved assignments for all hits in `hits`
def summarize_assignments(hits):
    ret = ""
    for hit in hits: 
        hid = hit['HITId']
        title =  hit['Title']
        name = "HIT %s: %s" % (hid, title)
        ret += name + "\n"
        assignments = get_all_assignments(hid)
        for a in assignments: 
            desc = "\tAssignment {aid}\n\t\tStatus: {status}\n".format(aid=a['AssignmentId'], status=a['AssignmentStatus'])
            ret += desc
    print(ret)

# %%
def refresh_hits(): 
    global hits 
    global MAX_RESULTS
    hits = cl.list_hits(MaxResults=MAX_RESULTS)['HITs']

# %% [markdown]
# # HIT monitoring

# %%
refresh_hits()
pass

# %%
refresh_hits()
summarize_hits(hits)
# Out:
# 9
# Title: Annotate the most important regions on graphic designs
# ID: 3KI0JD2ZU1RWFEWRUWBNM1DUM3Y761
# 	Assignments left: 1
# 	Assignments completed: 0
# 	Assignments pending: 8
# 	Expired: False
#
# Title: Annotate the most important regions on graphic designs
# ID: 31KPKEKW4AMO3FD25O7MI2PZSQ30BF
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 8
# 	Expired: False
#
# Title: Annotate the most important regions on graphic designs
# ID: 3UL5XDRDNCS4WO1WZITO8VVP1ST586
# 	Assignments left: 2
# 	Assignments completed: 0
# 	Assignments pending: 7
# 	Expired: False
#
# Title: Image Attention
# ID: 3FVBZG9CLJNYUSGO5GHI4DSXMZ30HH
# 	Assignments left: 0
# 	Assignments completed: 30
# 	Assignments pending: 0
# 	Expired: True
#
# Title: Image Attention
# ID: 3NC6WP7WJHT9Z8CYTMW3CBBO2NEWWO
# 	Assignments left: 0
# 	Assignments completed: 30
# 	Assignments pending: 0
# 	Expired: True
#
# Title: Annotate the most important regions on graphic designs
# ID: 3FJ2RVH25ZFCBW1JMRX4AKNO04X29Z
# 	Assignments left: 0
# 	Assignments completed: 10
# 	Assignments pending: 0
# 	Expired: True
#
# Title: Annotate the most important regions on graphic designs
# ID: 3GONHBMNHV7HORNP07AN2H3FLC2ZM2
# 	Assignments left: 0
# 	Assignments completed: 10
# 	Assignments pending: 0
# 	Expired: True
#
# Title: Annotate the most important regions on graphic designs
# ID: 37VHPF5VYCCPV9ABESGWM11ZSPSC8T
# 	Assignments left: 0
# 	Assignments completed: 10
# 	Assignments pending: 0
# 	Expired: True
#
# Title: Image Attention
# ID: 3EGKVCRQFW1L0A9NDWIVAUJJ3IZYBO
# 	Assignments left: 0
# 	Assignments completed: 90
# 	Assignments pending: 0
# 	Expired: True

# %%
refresh_hits()
summarize_assignments(hits)
pass
# Out:
# HIT 3FJ2RVH25ZFCBW1JMRX4AKNO04X29Z: Annotate the most important regions on graphic designs
# 	Assignment 3A4NIXBJ77906M4FB8OFILO3MYMLMG
# 		Status: Approved
# 	Assignment 3PB5A5BD0WG1ZRJRWBPAMBM5VSDG72
# 		Status: Approved
# 	Assignment 3UWN2HHPUZFTSHK57I0G7MRYJICNS4
# 		Status: Approved
# 	Assignment 3UN61F00HXZD1DEMOT4PNVMG6VR5R6
# 		Status: Approved
# 	Assignment 3TR2532VIQ4SMTVNL75LDAEPS9GJ6G
# 		Status: Approved
# 	Assignment 3R8YZBNQ9ISSCGD5Z7UMGPQ71FS7QU
# 		Status: Approved
# 	Assignment 3FFJ6VRIL2Y1D7P21044S8PY2RBI08
# 		Status: Approved
# 	Assignment 31LM9EDVOM20TE1FKOR2FL0BNZENJ3
# 		Status: Approved
# 	Assignment 3JRJSWSMQIVLEUMDO4WW9RPDDBB3E4
# 		Status: Approved
# 	Assignment 32Z9ZLUT1MUMKT61X3OUIXK10I6HO0
# 		Status: Submitted
# HIT 3GONHBMNHV7HORNP07AN2H3FLC2ZM2: Annotate the most important regions on graphic designs
# 	Assignment 3YOH7BII0AH8C3G640D5QHU1ORTVK4
# 		Status: Approved
# 	Assignment 37U1UTWH9WWWOVXOMRBSZFW78LPR8R
# 		Status: Approved
# 	Assignment 3SPJ033422DU5D5TRQ0DW1YIRJ2YJO
# 		Status: Approved
# 	Assignment 3U4J9857OFL58ABGGPXWL0V8FFOB7J
# 		Status: Approved
# 	Assignment 3QBD8R3Z22TS8HI6IW4BO8BXVCG4OV
# 		Status: Approved
# 	Assignment 3RSDURM96BWMUXJ1DPPMZLLQMB8EYL
# 		Status: Approved
# 	Assignment 37XITHEISXJY0YN133RX11SQYCICRQ
# 		Status: Approved
# 	Assignment 3N2BF7Y2VR4YKQLPKN9HQTVW5HUHMM
# 		Status: Approved
# 	Assignment 3I7DHKZYGOAGYN9DXY4V668X37WF51
# 		Status: Approved
# 	Assignment 3R3YRB5GRGD2NBIKNJQB0HPM58CAU1
# 		Status: Approved
# HIT 37VHPF5VYCCPV9ABESGWM11ZSPSC8T: Annotate the most important regions on graphic designs
# 	Assignment 3HMVI3QICK2NAWPP11U7S12WX2VY1D
# 		Status: Approved
# 	Assignment 3Y4W8Q93L0U0YXAWCJRIM4ZB4IWVDR
# 		Status: Approved
# 	Assignment 3X31TUMD7YW3AXIQIM5HYT00ONRL18
# 		Status: Approved
# 	Assignment 34S6N1K2ZWTEE834KB82QGG75CXLHH
# 		Status: Approved
# 	Assignment 3I0BTBYZAYVN37475IQ7EWJMSAPY0A
# 		Status: Approved
# 	Assignment 37UEWGM5HUIEDVD3N62DK59ZUFS1RQ
# 		Status: Approved
# 	Assignment 3CN4LGXD5YY42VM8OJD9QZ9Z9MH4Y8
# 		Status: Approved
# 	Assignment 3B4YI393VA6Q8UCAFEH26G146HQSSR
# 		Status: Approved
# 	Assignment 3A1PQ49WVIR1O1Z0R1QJ617T76IH1X
# 		Status: Approved
# 	Assignment 3D3VGR7TA1PANYRIAAGW8YOWSZMR3O
# 		Status: Approved

# %% [markdown]
# # Approve HITs

# %%
# Approves all outstanding hits created for the HITs in hits 
def approve_all(hits): 
    num_approved = 0
    for hit in hits: 
        # make sure you keep getting assignments 
        assignments = get_all_assignments(hit["HITId"])
        #print(assignments)
        for a in assignments: 
            if a['AssignmentStatus'] != 'Approved':
                print("Approving assignment")
                num_approved += 1
                cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Approved %d assignments" % num_approved)

# %%
refresh_hits()
approve_all(hits)
# Out:
# Approving assignment
# Approved 1 assignments

# %% [markdown]
# # Update expiration or num tasks

# %%
import datetime 

# changes the expiration date on a HIT to days_from_now days in the future
def update_expiration(hitid, days_from_now): 
    if ALLOW_UPDATE_EXPIRATION: 
        days = days_from_now*datetime.timedelta(days=1)
        expire_time = datetime.datetime.now() + days

        response = cl.update_expiration_for_hit(HITId=hitid, ExpireAt=expire_time)
        print(response)
        return response
    else: 
        raise RuntimeException("This action is not currently enabled; set `ALLOW_UPDATE_EXPIRATION` to true to proceed with this action")
    
def expire_hit(hit): 
    return update_expiration(hit, -10)

# %%
def add_assignments(hitid, num_assignments): 
    if ALLOW_ASSIGNMENT_ADDITION: 
        response = cl.create_additional_assignments_for_hit(
            HITId=hitid,
            NumberOfAdditionalAssignments=num_assignments
        )
        print(response)
        return response
    else: 
        raise RuntimException("This action is not currently enabled; set `ALLOW_ASSIGNMENT_ADDITION` to true to proceed with this action")

# %% [markdown]
# # Add custom qualifications

# %% [markdown]
# ## Add a qualification to disqualify workers who have done work before
#
# - uses "negative qualification" method from https://github.com/cloudyr/MturkR/wiki/qualifications-as-blocks
#
# ### NOTE: quals are kept separate for the sandbox and prod. Make sure you are creating and assigning your quals in prod.

# %%
# structure of a new qualification 
NEW_QUAL = {
    'Name': 'qualName',
    'Keywords': 'Keywords for qual',
    'Description': 'What is this qual, and why are you assigning it?',
    'QualificationTypeStatus': 'Active',
    'AutoGranted': False
}

# %%
def create_qual(new_qual):
    if ALLOW_CREATE_QUAL: 
        response = cl.create_qualification_type(**new_qual)
        print(response)
        Id = response['QualificationTypeId']
        print("id", Id)
        return Id
    else: 
        raise RuntimException("This action is not currently enabled; set `ALLOW_CREATE_QUAL` to true to proceed with this action")

# %%
# Gets all the custom quals you have created. 
def list_quals(): 
    response = cl.list_qualification_types(
            Query='hasCompletedVisualGraphRecallTask',
            MustBeRequestable=False
    )
    print(response)

list_quals()
# Out:
# {'NumResults': 0, 'QualificationTypes': [], 'ResponseMetadata': {'RequestId': '4ff9cff9-32f4-49b2-b79a-0137726813e0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '4ff9cff9-32f4-49b2-b79a-0137726813e0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '40', 'date': 'Tue, 27 Nov 2018 21:11:39 GMT'}, 'RetryAttempts': 0}}

# %%
def assign_qual(qual_id, worker_ids): 
    for worker in worker_ids: 
        response = cl.associate_qualification_with_worker(
                QualificationTypeId=qual_id, 
                WorkerId=worker,
                IntegerValue=1,
                SendNotification=False
        )
        print(response)
        assert response
        
def get_workers_for_hit(hitid): 
    a = get_all_assignments(hitid)
    workers = [a_['WorkerId'] for a_ in a]
    return workers
    
def confirm_quals(qual_id, worker_ids): 
    for w in worker_ids: 
        response = cl.get_qualification_score(
                QualificationTypeId=qual_id,
                WorkerId=w
        )
        response = response['Qualification']
        assert response['Status'] == 'Granted'
        assert response['IntegerValue'] == 1
        
# Assigns qual with `qual_id` to every worker who has completed an assignment for the hit with `hitid`
def assign_qual_for_hit(hitid, qual_id): 
    workers = get_workers_for_hit(hitid)
    print("got workers")
    assign_qual(qual_id, workers)
    print("assigned qual")
    confirm_quals(qual_id, workers)
    print("confirmed qual")

# %% [markdown]
# # Download data

# %%
from bs4 import BeautifulSoup as bs 
import pprint

def pretty_print(obj):
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(obj)
    pp = None

# Downloads all the assignments completed for `hits` as a list of dictionaries. 
# If a download_path is given, also saves that data as json 
def get_assignment_content(hits, download_path="", should_print=False): 
    all_responses = []
    for hit in hits: 
        hitid = hit['HITId']
        assignments = get_all_assignments(hitid)
        print(hitid)
        print(assignments)
        for a in assignments:
            #print(a)
            a_xml = a['Answer']
            #print(a_xml)
            soup = bs(a_xml, "lxml")
            answers = soup.find_all("answer")
            #print(answers)
            results = {'HITId': hitid}
            for ans in answers: 
                identifier = ans.find('questionidentifier').string
                answer = ans.find('freetext').string
                try: 
                    results[identifier] = json.loads(answer)
                except:
                    results[identifier] = answer
            all_responses.append(results)
    if should_print: 
        pretty_print(all_responses)
    if download_path: 
        with open(download_path, 'w') as outfile: 
            json.dump(all_responses, outfile)
    return all_responses

# %%
responses = get_assignment_content(hits, download_path='responses_prod_test3.json', should_print=False)
len(responses)
# Out:
# 3FJ2RVH25ZFCBW1JMRX4AKNO04X29Z
# [{'AssignmentId': '3A4NIXBJ77906M4FB8OFILO3MYMLMG', 'WorkerId': 'A25PFSORDO3SWQ', 'HITId': '3FJ2RVH25ZFCBW1JMRX4AKNO04X29Z', 'AssignmentStatus': 'Approved', 'AutoApprovalTime': datetime.datetime(2019, 2, 8, 20, 6, 56, tzinfo=tzlocal()), 'AcceptTime': datetime.datetime(2019, 2, 1, 19, 53, 2, tzinfo=tzlocal()), 'SubmitTime': datetime.datetime(2019, 2, 1, 20, 6, 56, tzinfo=tzlocal()), 'ApprovalTime': datetime.datetime(2019, 2, 1, 22, 24, 33, tzinfo=tzlocal()), 'Answer': '<?xml version="1.0" encoding="ASCII"?><QuestionFormAnswers xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2005-10-01/QuestionFormAnswers.xsd"><Answer><QuestionIdentifier>workerId</QuestionIdentifier><FreeText>A25PFSORDO3SWQ</FreeText></Answer><Answer><QuestionIdentifier>results</QuestionIdentifier><FreeText>{"inputs":[],"outputs":[["240,600,https://www.dropbox.com/s/bi9qrcr1zxu4659/infographics_1_3_MAB2CQ_1UW0_notext.png?raw=1:3,4,1,24,29,24,29,27,133,232,133,234,29,24,29,;3,4,1,50,163,50,163,61,207,118,212,97,161,50,163,;3,4,1,45,236,45,236,51,267,69,267,85,284,104,285,113,259,102,244,69,234,45,236,;","240,600,https://www.dropbox.com/s/8wx1aaeo596gxhs/infographics_1_26_MACW2lF5fbY_notext.png?raw=1:3,4,1,37,186,37,186,43,217,57,219,50,184,37,186,;3,2,1,33,318,34,319,35,320,36,321,37,323,38,325,39,325,39,326,40,328,42,331,43,332,43,333,43,334,45,336,46,337,46,338,48,339,48,340,48,342,50,345,50,346,51,347,51,348,52,348,54,348,55,348,57,348,59,348,60,348,61,348,63,348,64,345,65,343,66,340,67,339,67,336,67,335,67,333,67,331,67,330,67,329,67,328,67,327,67,326,67,325,66,324,65,323,63,321,62,321,61,320,60,320,59,318,58,318,58,317,57