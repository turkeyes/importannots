# %% [markdown]
# # Notebook to generate fold text files for the mturk task
#
# This notebook generates fold.txt files for each element in the canva_scarping2 dataset.
#
# Each fold.txt will contain 5-10 image names from the canva_scraping2 dataset. The image names will be links to Dropbox, as the canva_scraping2 dataset is hosted there.
#
# Folds can be built with a mix of multiple classes in each one of them, as to avoid having only book-covers or web-ads in each fold.
#
# Example structure of a fold.txt file:
#
# https://www.dropbox.com/s/gp9snrmlc54d3vo/certificates_1_18_MACS_ooy31s.png?raw=1
# https://www.dropbox.com/s/c32nwr8y37sw3or/certificates_1_10_MACTFpwVtmk.png?raw=1
#
# .
# .
# .
# .

# %%
# Imports
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json

# %%
# Constants
USE_FULL_DATASET = True
CLASSES_TO_USE = None
WITH_TEXT = True
FILES_PER_FOLD = 10
DATASET_PATH = '../canva_scraping2_clean'
FOLD_OUTPUT_DIR = './files'

# %% [markdown]
# ## Dataset stats

# %%
# Get statistics on canva_scraping2

# Get folder names
canva_scraping2_folders = [f for f in os.listdir(DATASET_PATH) if '_' not in f and '.' not in f and os.path.isdir(os.path.join(DATASET_PATH,f))]
print('Data folders in canva_scraping2:', canva_scraping2_folders)

num_elems_in_full_dataset = 0

SUBFOLDER = 'png_clean'

# Get number of elements in folders
for fol in canva_scraping2_folders:
    num_elems = len([p for p in os.listdir(os.path.join(DATASET_PATH, fol, 'png_clean')) if p.endswith('png')])
    print('Number of elements in folder %s: %d' % (fol, num_elems))
    num_elems_in_full_dataset += num_elems
    
print('Num elems in full dataset:', num_elems_in_full_dataset)
# Out:
# Data folders in canva_scraping2: ['book-covers', 'cd-covers', 'certificates', 'coupons', 'cvs', 'infographics', 'magazine-covers', 'posters', 'social-graphics', 'web-ads']
# Number of elements in folder book-covers: 363
# Number of elements in folder cd-covers: 28
# Number of elements in folder certificates: 216
# Number of elements in folder coupons: 175
# Number of elements in folder cvs: 123
# Number of elements in folder infographics: 148
# Number of elements in folder magazine-covers: 37
# Number of elements in folder posters: 1677
# Number of elements in folder social-graphics: 1123
# Number of elements in folder web-ads: 212
# Num elems in full dataset: 4102

# %% [markdown]
# ## Generate fold files

# %%
## Helper functions
def get_all_design_names(data_path, classes_to_use, subfolder='png'):    
    names_dict = {}
    
    for cl in classes_to_use:
        names_dict[cl] = []
    
    
    for cl in classes_to_use: 
        names_dict[cl] = [p for p in os.listdir(os.path.join(data_path, cl, subfolder)) if p.endswith('png')]
        
    return names_dict

## Generate fold files
def generate_fold_files(data_path, output_dir, classes_to_use = None, 
                        files_per_fold = 10, mix_classes = True, 
                        files_to_generate = 2, fold_prefix='fold', verbose = True, subfolder='png'):
    
    if not classes_to_use:
        classes_to_use = [f for f in os.listdir(DATASET_PATH) if '_' not in f and '.' not in f and os.path.isdir(os.path.join(DATASET_PATH,f))]

    
    num_folds_generated = 0
    unused_design_names = get_all_design_names(data_path, classes_to_use, subfolder=subfolder)
    
    while unused_design_names and num_folds_generated<files_to_generate:
        fold_txt_name = fold_prefix+str(num_folds_generated)+'.txt'
        fold_path = os.path.join(output_dir, fold_txt_name)
        
        generate_one_fold_file(fold_path, unused_design_names, files_per_fold, subfolder=subfolder)
        
        num_folds_generated +=1
        
        if verbose:
            print('Fold %s generated. %d files generated so far.' % (fold_txt_name, num_folds_generated))
        
    print('Done.')    
        
            
def generate_one_fold_file(fold_path, unused_design_names, files_per_fold, verbose =1, subfolder='png'):
    
    first_pass = True
    with open(fold_path, 'w+') as f:
        for _ in range(files_per_fold):
            if unused_design_names:
                # Sample a class
                cl = np.random.choice(list(unused_design_names.keys()))
                if verbose: print('chosen class:', cl)

                # Get a design name from that class
                design = np.random.choice(unused_design_names[cl])
                link = get_dropbox_link(design, cl, subfolder=subfolder)
                if verbose: print('Adding dropbox link to fold:', link)

                # Add to fold
                if not first_pass:
                    f.write('\n')
                f.write(link)
                first_pass=False

                # Remove that design from the list of usable designs
                unused_design_names[cl].remove(design)
                if not unused_design_names[cl]:
                    del unused_design_names[cl]
            
    return unused_design_names


def get_dropbox_link(design, cl, 
                     subfolder='png', 
                     create_link_first=True, 
                     base_folder = "/Graduate Studies/Harvard/AC299r Independent Research/canva_scraping2_clean/"):
    '''
    Uses the Dropbox API to get a shared dropbox link to a given design. The design must be located in:
    /Graduate Studies/Harvard/AC299r Independent Research/canva_scraping2_clean/"+cl+"/"+subfolder+"/"+design
    
    Inputs
    -----
    design: name of the design to get link for
    subfolder: subfolder where the design ois located, usually one of 'png', 'png_clean'
    create_link_first: if True, first tries to create the link before asking for the existing one. 
    This should be changed to False when most 
    base_folder: folder where the designs are located
    
    '''
    
    print('Trying to get dropbox link for',design)
    
    if create_link_first:
        url = "https://api.dropboxapi.com/2/sharing/create_shared_link_with_settings"
    else:
        url = "https://api.dropboxapi.com/2/sharing/list_shared_links"

    headers = {
        "Authorization": "Bearer -EVBtUP70JYAAAAAAACNue90xxn9wbCjB4RAZoE8Ys1buD7eEu0GRzbhD9XQqM9O",
        "Content-Type": "application/json"
    }

    data = {
        "path": base_folder+cl+"/"+subfolder+"/"+design
    }

    r = requests.post(url, headers=headers, data=json.dumps(data))    
    
    print(r.text) 
    
    if create_link_first:
        if 'error_summary' in r.json() and 'already_exists' in r.json()['error_summary']:
            print('Error found! Link already exists. Getting existing link...')
            url = "https://api.dropboxapi.com/2/sharing/list_shared_links"
            r = requests.post(url, headers=headers, data=json.dumps(data)) 
            link = r.json()['links'][0]['url'][:-4]+'raw=1'  
        else:
            link = r.json()['url'][:-4]+'raw=1'
    else:
        if not r.json()['links']:
            print('Error found! Shared link not created. Creating link...')
            url = "https://api.dropboxapi.com/2/sharing/create_shared_link_with_settings"
            r = requests.post(url, headers=headers, data=json.dumps(data)) 
            link = r.json()['url'][:-4]+'raw=1'
        else:
            link = r.json()['links'][0]['url'][:-4]+'raw=1'
    
    return link


def dropbox_links_to_file_loc(dropbox_links, mid_folder='png'):
    file_locs = []
    for d in dropbox_links:
        name = d.split('/')[-1].split('?')[0]
        cl = name.split('_')[0]
        
        file_locs.append(os.path.join(cl, mid_folder, name))
        
    return file_locs

# %%
# Testing the get_dropbox_link function
get_dropbox_link('posters_50_4_MACffVAezac.png', 'posters', subfolder='png_clean',create_link_first=False)

# %%
DATASET_PATH = '../canva_scraping2_clean'

generate_fold_files(data_path=DATASET_PATH, 
                    output_dir=FOLD_OUTPUT_DIR, 
                    classes_to_use=['posters'], # if None, all classes will be used
                    files_per_fold = 10, 
                    mix_classes=True, 
                    files_to_generate=15,
                    fold_prefix = 'fold_poster_clean',
                    subfolder = 'png_clean')
# Out:
# {".tag": "file", "url": "https://www.dropbox.com/s/dw98ltlufhjs5t6/posters_49_8_MACTkoEUSkc.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfp0g", "name": "posters_49_8_MACTkoEUSkc.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_49_8_mactkoeuskc.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:18:20Z", "server_modified": "2019-02-14T03:40:14Z", "rev": "e4a831185b318", "size": 174872}
# Adding dropbox link to fold: https://www.dropbox.com/s/dw98ltlufhjs5t6/posters_49_8_MACTkoEUSkc.png?raw=1
# Fold fold_poster_clean3.txt generated. 4 files generated so far.
# chosen class: posters
# Trying to get dropbox link for posters_34_33_MAB-r3idwRI.png
# {".tag": "file", "url": "https://www.dropbox.com/s/hqwcykpfsiku1pf/posters_34_33_MAB-r3idwRI.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfoPw", "name": "posters_34_33_MAB-r3idwRI.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_34_33_mab-r3idwri.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:15:48Z", "server_modified": "2019-02-13T23:57:36Z", "rev": "e486e1185b318", "size": 35402}
# Adding dropbox link to fold: https://www.dropbox.com/s/hqwcykpfsiku1pf/posters_34_33_MAB-r3idwRI.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_4_31_MACU4ySlN0Q.png
# {".tag": "file", "url": "https://www.dropbox.com/s/bvqmhjb2kd4yhf9/posters_4_31_MACU4ySlN0Q.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfp6Q", "name": "posters_4_31_MACU4ySlN0Q.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_4_31_macu4ysln0q.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:18:28Z", "server_modified": "2019-02-14T03:40:25Z", "rev": "e4c0b1185b318", "size": 58774}
# Adding dropbox link to fold: https://www.dropbox.com/s/bvqmhjb2kd4yhf9/posters_4_31_MACU4ySlN0Q.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_10_24_MACVRicsIu0.png
# {"error_summary": "shared_link_already_exists/..", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/khtfmw4pq6tob54/posters_10_24_MACVRicsIu0.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_38_2_MACcfW7eBrE.png
# {".tag": "file", "url": "https://www.dropbox.com/s/k5a700a8o0ny9kv/posters_38_2_MACcfW7eBrE.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfonw", "name": "posters_38_2_MACcfW7eBrE.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_38_2_maccfw7ebre.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:22Z", "server_modified": "2019-02-13T23:57:22Z", "rev": "e47e91185b318", "size": 290037}
# Adding dropbox link to fold: https://www.dropbox.com/s/k5a700a8o0ny9kv/posters_38_2_MACcfW7eBrE.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_63_9_MAB9YNjMq84.png
# {".tag": "file", "url": "https://www.dropbox.com/s/jhji0epmqzawvtk/posters_63_9_MAB9YNjMq84.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfrdA", "name": "posters_63_9_MAB9YNjMq84.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_63_9_mab9ynjmq84.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:21:04Z", "server_modified": "2019-02-14T03:40:25Z", "rev": "e4c901185b318", "size": 62920}
# Adding dropbox link to fold: https://www.dropbox.com/s/jhji0epmqzawvtk/posters_63_9_MAB9YNjMq84.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_5_10_MAB9Xzal25Q.png
# {".tag": "file", "url": "https://www.dropbox.com/s/yhwxy5qsgin5ufp/posters_5_10_MAB9Xzal25Q.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfq7Q", "name": "posters_5_10_MAB9Xzal25Q.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_5_10_mab9xzal25q.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:20:14Z", "server_modified": "2019-02-14T03:40:25Z", "rev": "e4c5a1185b318", "size": 77918}
# Adding dropbox link to fold: https://www.dropbox.com/s/yhwxy5qsgin5ufp/posters_5_10_MAB9Xzal25Q.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_13_20_MAB2VTlBySg.png
# {".tag": "file", "url": "https://www.dropbox.com/s/g1onfuarlegltld/posters_13_20_MAB2VTlBySg.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfl3w", "name": "posters_13_20_MAB2VTlBySg.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_13_20_mab2vtlbysg.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:12:14Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e45191185b318", "size": 81130}
# Adding dropbox link to fold: https://www.dropbox.com/s/g1onfuarlegltld/posters_13_20_MAB2VTlBySg.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_38_19_MACXC9ZC7gk.png
# {".tag": "file", "url": "https://www.dropbox.com/s/57kgr264tjv10gi/posters_38_19_MACXC9ZC7gk.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfolw", "name": "posters_38_19_MACXC9ZC7gk.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_38_19_macxc9zc7gk.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:18Z", "server_modified": "2019-02-13T23:57:36Z", "rev": "e48ab1185b318", "size": 76620}
# Adding dropbox link to fold: https://www.dropbox.com/s/57kgr264tjv10gi/posters_38_19_MACXC9ZC7gk.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_15_33_MACRPwnDns0.png
# {".tag": "file", "url": "https://www.dropbox.com/s/d1axopjmj25877g/posters_15_33_MACRPwnDns0.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfmGw", "name": "posters_15_33_MACRPwnDns0.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_15_33_macrpwndns0.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:12:36Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e45551185b318", "size": 78945}
# Adding dropbox link to fold: https://www.dropbox.com/s/d1axopjmj25877g/posters_15_33_MACRPwnDns0.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_19_12_MACW-UmA6aw.png
# {".tag": "file", "url": "https://www.dropbox.com/s/gfbvpc29dgmlv2e/posters_19_12_MACW-UmA6aw.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfmbA", "name": "posters_19_12_MACW-UmA6aw.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_19_12_macw-uma6aw.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:13:06Z", "server_modified": "2019-02-13T23:57:00Z", "rev": "e46771185b318", "size": 82181}
# Adding dropbox link to fold: https://www.dropbox.com/s/gfbvpc29dgmlv2e/posters_19_12_MACW-UmA6aw.png?raw=1
# Fold fold_poster_clean4.txt generated. 5 files generated so far.
# chosen class: posters
# Trying to get dropbox link for posters_60_23_MACWl7hjSPk.png
# {".tag": "file", "url": "https://www.dropbox.com/s/k6zp0rsaowz1365/posters_60_23_MACWl7hjSPk.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfrEg", "name": "posters_60_23_MACWl7hjSPk.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_60_23_macwl7hjspk.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:20:30Z", "server_modified": "2019-02-14T03:40:56Z", "rev": "e50391185b318", "size": 172817}
# Adding dropbox link to fold: https://www.dropbox.com/s/k6zp0rsaowz1365/posters_60_23_MACWl7hjSPk.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_10_23_MACX5O-3WAc.png
# {".tag": "file", "url": "https://www.dropbox.com/s/feugqgkc5qfnic0/posters_10_23_MACX5O-3WAc.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABflnw", "name": "posters_10_23_MACX5O-3WAc.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_10_23_macx5o-3wac.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:11:50Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e44d91185b318", "size": 131087}
# Adding dropbox link to fold: https://www.dropbox.com/s/feugqgkc5qfnic0/posters_10_23_MACX5O-3WAc.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_42_24_MACS7IWA8aU.png
# {".tag": "file", "url": "https://www.dropbox.com/s/vy72qa7dxc9r5md/posters_42_24_MACS7IWA8aU.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfpHw", "name": "posters_42_24_MACS7IWA8aU.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_42_24_macs7iwa8au.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:17:10Z", "server_modified": "2019-02-14T03:40:32Z", "rev": "e4d811185b318", "size": 170109}
# Adding dropbox link to fold: https://www.dropbox.com/s/vy72qa7dxc9r5md/posters_42_24_MACS7IWA8aU.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_51_18_MACW3MryIdM.png
# {".tag": "file", "url": "https://www.dropbox.com/s/1wny1j344hl7zjp/posters_51_18_MACW3MryIdM.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfqFA", "name": "posters_51_18_MACW3MryIdM.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_51_18_macw3mryidm.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:18:42Z", "server_modified": "2019-02-14T03:40:45Z", "rev": "e4e421185b318", "size": 163879}
# Adding dropbox link to fold: https://www.dropbox.com/s/1wny1j344hl7zjp/posters_51_18_MACW3MryIdM.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_39_20_MACZxpWlBlk.png
# {".tag": "file", "url": "https://www.dropbox.com/s/ruzl9ts4pmgpspj/posters_39_20_MACZxpWlBlk.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfosg", "name": "posters_39_20_MACZxpWlBlk.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_39_20_maczxpwlblk.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:28Z", "server_modified": "2019-02-14T03:40:32Z", "rev": "e4d451185b318", "size": 93125}
# Adding dropbox link to fold: https://www.dropbox.com/s/ruzl9ts4pmgpspj/posters_39_20_MACZxpWlBlk.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_26_5_MACSXU_Cm7w.png
# {"error_summary": "shared_link_already_exists/.", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/pjnfr6w0a512n4q/posters_26_5_MACSXU_Cm7w.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_25_34_MACU-4EdfGE.png
# {".tag": "file", "url": "https://www.dropbox.com/s/qkehy4ry571kazo/posters_25_34_MACU-4EdfGE.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfnNg", "name": "posters_25_34_MACU-4EdfGE.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_25_34_macu-4edfge.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:14:20Z", "server_modified": "2019-02-13T23:57:22Z", "rev": "e47411185b318", "size": 40947}
# Adding dropbox link to fold: https://www.dropbox.com/s/qkehy4ry571kazo/posters_25_34_MACU-4EdfGE.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_17_29_MACY7uCd56w.png
# {".tag": "file", "url": "https://www.dropbox.com/s/ibiyrj6xu7dfve3/posters_17_29_MACY7uCd56w.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfmSA", "name": "posters_17_29_MACY7uCd56w.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_17_29_macy7ucd56w.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:12:54Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e45821185b318", "size": 61128}
# Adding dropbox link to fold: https://www.dropbox.com/s/ibiyrj6xu7dfve3/posters_17_29_MACY7uCd56w.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_62_10_MACY0vLS_4A.png
# {".tag": "file", "url": "https://www.dropbox.com/s/u8apapqqaxdfxue/posters_62_10_MACY0vLS_4A.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfrPA", "name": "posters_62_10_MACY0vLS_4A.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_62_10_macy0vls_4a.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:20:44Z", "server_modified": "2019-02-14T03:40:56Z", "rev": "e50551185b318", "size": 303907}
# Adding dropbox link to fold: https://www.dropbox.com/s/u8apapqqaxdfxue/posters_62_10_MACY0vLS_4A.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_66_19_MACWL9XHviw.png
# {".tag": "file", "url": "https://www.dropbox.com/s/plp46hxnttqdys3/posters_66_19_MACWL9XHviw.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfrpw", "name": "posters_66_19_MACWL9XHviw.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_66_19_macwl9xhviw.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:21:26Z", "server_modified": "2019-02-14T03:40:56Z", "rev": "e509e1185b318", "size": 57871}
# Adding dropbox link to fold: https://www.dropbox.com/s/plp46hxnttqdys3/posters_66_19_MACWL9XHviw.png?raw=1
# Fold fold_poster_clean5.txt generated. 6 files generated so far.
# chosen class: posters
# Trying to get dropbox link for posters_37_2_MACTrorBJhw.png
# {".tag": "file", "url": "https://www.dropbox.com/s/m3ovr4f3wy4b761/posters_37_2_MACTrorBJhw.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfogw", "name": "posters_37_2_MACTrorBJhw.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_37_2_mactrorbjhw.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:14Z", "server_modified": "2019-02-13T23:57:22Z", "rev": "e47df1185b318", "size": 198401}
# Adding dropbox link to fold: https://www.dropbox.com/s/m3ovr4f3wy4b761/posters_37_2_MACTrorBJhw.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_45_0_MACTlhUKbMo.png
# {"error_summary": "shared_link_already_exists/..", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/stbj5h13ftmul0d/posters_45_0_MACTlhUKbMo.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_29_24_MACZGlIfzQo.png
# {".tag": "file", "url": "https://www.dropbox.com/s/fb192cpgsl3fqzy/posters_29_24_MACZGlIfzQo.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfnmA", "name": "posters_29_24_MACZGlIfzQo.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_29_24_maczglifzqo.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:14:54Z", "server_modified": "2019-02-13T23:57:36Z", "rev": "e48061185b318", "size": 291178}
# Adding dropbox link to fold: https://www.dropbox.com/s/fb192cpgsl3fqzy/posters_29_24_MACZGlIfzQo.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_32_27_MACYc4JH5mE.png
# {".tag": "file", "url": "https://www.dropbox.com/s/rjts3w69jc1zhqj/posters_32_27_MACYc4JH5mE.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfoBA", "name": "posters_32_27_MACYc4JH5mE.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_32_27_macyc4jh5me.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:15:32Z", "server_modified": "2019-02-13T23:57:36Z", "rev": "e48401185b318", "size": 242356}
# Adding dropbox link to fold: https://www.dropbox.com/s/rjts3w69jc1zhqj/posters_32_27_MACYc4JH5mE.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_11_10_MABu0Dn0nhg.png
# {".tag": "file", "url": "https://www.dropbox.com/s/dfhuinn7f8nypid/posters_11_10_MABu0Dn0nhg.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABflqQ", "name": "posters_11_10_MABu0Dn0nhg.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_11_10_mabu0dn0nhg.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:11:54Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e44e31185b318", "size": 246803}
# Adding dropbox link to fold: https://www.dropbox.com/s/dfhuinn7f8nypid/posters_11_10_MABu0Dn0nhg.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_47_20_MACPosFERFc.png
# {"error_summary": "shared_link_already_exists/.", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/6o7tvcz5r7tcu17/posters_47_20_MACPosFERFc.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_6_21_MACXD6a0Wkg.png
# {".tag": "file", "url": "https://www.dropbox.com/s/alc7bdchekskgzr/posters_6_21_MACXD6a0Wkg.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfrxg", "name": "posters_6_21_MACXD6a0Wkg.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_6_21_macxd6a0wkg.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:21:36Z", "server_modified": "2019-02-14T03:40:25Z", "rev": "e4cb11185b318", "size": 51975}
# Adding dropbox link to fold: https://www.dropbox.com/s/alc7bdchekskgzr/posters_6_21_MACXD6a0Wkg.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_37_9_MACTqpQLMv0.png
# {".tag": "file", "url": "https://www.dropbox.com/s/oer4k8lh2lo7d3o/posters_37_9_MACTqpQLMv0.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfojg", "name": "posters_37_9_MACTqpQLMv0.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_37_9_mactqpqlmv0.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:16Z", "server_modified": "2019-02-13T23:57:22Z", "rev": "e47e61185b318", "size": 359319}
# Adding dropbox link to fold: https://www.dropbox.com/s/oer4k8lh2lo7d3o/posters_37_9_MACTqpQLMv0.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_31_29_MACXmt9oGWc.png
# {".tag": "file", "url": "https://www.dropbox.com/s/ljzi1g5txnu2aft/posters_31_29_MACXmt9oGWc.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfn7A", "name": "posters_31_29_MACXmt9oGWc.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_31_29_macxmt9ogwc.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:15:24Z", "server_modified": "2019-02-13T23:57:36Z", "rev": "e48311185b318", "size": 61350}
# Adding dropbox link to fold: https://www.dropbox.com/s/ljzi1g5txnu2aft/posters_31_29_MACXmt9oGWc.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_34_8_MACcScaVSTU.png
# {"error_summary": "shared_link_already_exists/.", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/w6a74ij47ajto9w/posters_34_8_MACcScaVSTU.png?raw=1
# Fold fold_poster_clean6.txt generated. 7 files generated so far.
# chosen class: posters
# Trying to get dropbox link for posters_39_31_MACahnNoLgY.png
# {".tag": "file", "url": "https://www.dropbox.com/s/2hjo0ujepqo8wbw/posters_39_31_MACahnNoLgY.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfovA", "name": "posters_39_31_MACahnNoLgY.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_39_31_macahnnolgy.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:32Z", "server_modified": "2019-02-14T03:40:32Z", "rev": "e4d4e1185b318", "size": 52958}
# Adding dropbox link to fold: https://www.dropbox.com/s/2hjo0ujepqo8wbw/posters_39_31_MACahnNoLgY.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_5_31_MACXn4nJ8hA.png
# {"error_summary": "shared_link_already_exists/..", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/dbsd40rj8m694l9/posters_5_31_MACXn4nJ8hA.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_15_25_MACfChoNQbM.png
# {".tag": "file", "url": "https://www.dropbox.com/s/ih8urf48fkgmvha/posters_15_25_MACfChoNQbM.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfmEw", "name": "posters_15_25_MACfChoNQbM.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_15_25_macfchonqbm.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:12:34Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e454d1185b318", "size": 49608}
# Adding dropbox link to fold: https://www.dropbox.com/s/ih8urf48fkgmvha/posters_15_25_MACfChoNQbM.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_25_0_MACcZP_LW3M.png
# {"error_summary": "shared_link_already_exists/.", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/aqzah736zi3uajf/posters_25_0_MACcZP_LW3M.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_63_31_MACa984WoC0.png
# {".tag": "file", "url": "https://www.dropbox.com/s/prm040032f2e0bo/posters_63_31_MACa984WoC0.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfraw", "name": "posters_63_31_MACa984WoC0.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_63_31_maca984woc0.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:21:02Z", "server_modified": "2019-02-14T03:40:56Z", "rev": "e50781185b318", "size": 61811}
# Adding dropbox link to fold: https://www.dropbox.com/s/prm040032f2e0bo/posters_63_31_MACa984WoC0.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_1_26_MABy8aWgiro.png
# {".tag": "file", "url": "https://www.dropbox.com/s/ymwb3wo9xmrutw5/posters_1_26_MABy8aWgiro.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfmlA", "name": "posters_1_26_MABy8aWgiro.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_1_26_maby8awgiro.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:13:22Z", "server_modified": "2019-02-13T23:57:00Z", "rev": "e469f1185b318", "size": 212008}
# Adding dropbox link to fold: https://www.dropbox.com/s/ymwb3wo9xmrutw5/posters_1_26_MABy8aWgiro.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_6_5_MACiarCUPH8.png
# {"error_summary": "shared_link_already_exists/.", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/ltp3325kv7v04fc/posters_6_5_MACiarCUPH8.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_31_30_MACbGe5y4q0.png
# {".tag": "file", "url": "https://www.dropbox.com/s/rrfgd8l2pddux01/posters_31_30_MACbGe5y4q0.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfn7g", "name": "posters_31_30_MACbGe5y4q0.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_31_30_macbge5y4q0.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:15:24Z", "server_modified": "2019-02-13T23:57:36Z", "rev": "e48321185b318", "size": 155067}
# Adding dropbox link to fold: https://www.dropbox.com/s/rrfgd8l2pddux01/posters_31_30_MACbGe5y4q0.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_30_3_MACdmCygIdo.png
# {".tag": "file", "url": "https://www.dropbox.com/s/o3rjmurykvxunf7/posters_30_3_MACdmCygIdo.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfn2Q", "name": "posters_30_3_MACdmCygIdo.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_30_3_macdmcygido.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:15:16Z", "server_modified": "2019-02-13T23:57:22Z", "rev": "e47ae1185b318", "size": 84349}
# Adding dropbox link to fold: https://www.dropbox.com/s/o3rjmurykvxunf7/posters_30_3_MACdmCygIdo.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_35_5_MACPqfWPLZY.png
# {".tag": "file", "url": "https://www.dropbox.com/s/4l46pdormuj1ngo/posters_35_5_MACPqfWPLZY.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfoXA", "name": "posters_35_5_MACPqfWPLZY.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_35_5_macpqfwplzy.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:16:00Z", "server_modified": "2019-02-13T23:57:22Z", "rev": "e47d71185b318", "size": 377190}
# Adding dropbox link to fold: https://www.dropbox.com/s/4l46pdormuj1ngo/posters_35_5_MACPqfWPLZY.png?raw=1
# Fold fold_poster_clean7.txt generated. 8 files generated so far.
# chosen class: posters
# Trying to get dropbox link for posters_56_11_MACTHTzFWdo.png
# {".tag": "file", "url": "https://www.dropbox.com/s/02tyq4ufzx3z0vc/posters_56_11_MACTHTzFWdo.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfqiw", "name": "posters_56_11_MACTHTzFWdo.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_56_11_macthtzfwdo.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:19:32Z", "server_modified": "2019-02-14T03:40:45Z", "rev": "e4e911185b318", "size": 362795}
# Adding dropbox link to fold: https://www.dropbox.com/s/02tyq4ufzx3z0vc/posters_56_11_MACTHTzFWdo.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_15_27_MACY7nvROpE.png
# {".tag": "file", "url": "https://www.dropbox.com/s/3b86km00bj5msrf/posters_15_27_MACY7nvROpE.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfmFQ", "name": "posters_15_27_MACY7nvROpE.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_15_27_macy7nvrope.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:12:34Z", "server_modified": "2019-02-13T23:56:47Z", "rev": "e454f1185b318", "size": 26494}
# Adding dropbox link to fold: https://www.dropbox.com/s/3b86km00bj5msrf/posters_15_27_MACY7nvROpE.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_63_32_MACXtqcvddI.png
# {"error_summary": "shared_link_already_exists/..", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/fimhd44zlehh54i/posters_63_32_MACXtqcvddI.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_34_23_MACXtrg56G0.png
# {"error_summary": "shared_link_already_exists/..", "error": {".tag": "shared_link_already_exists"}}
# Error found! Link already exists. Getting existing link...
# Adding dropbox link to fold: https://www.dropbox.com/s/2vb1po5qkq1x0kf/posters_34_23_MACXtrg56G0.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_59_21_MACWYe21MvA.png
# {".tag": "file", "url": "https://www.dropbox.com/s/9zrqt5q3wj0syhu/posters_59_21_MACWYe21MvA.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfq4A", "name": "posters_59_21_MACWYe21MvA.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_59_21_macwye21mva.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:20:10Z", "server_modified": "2019-02-14T03:40:45Z", "rev": "e4ece1185b318", "size": 81430}
# Adding dropbox link to fold: https://www.dropbox.com/s/9zrqt5q3wj0syhu/posters_59_21_MACWYe21MvA.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_22_33_MACcZtzkXaE.png
# {".tag": "file", "url": "https://www.dropbox.com/s/ec4pxysnbsxlsqw/posters_22_33_MACcZtzkXaE.png?dl=0", "id": "id:g5a_GhGF1jAAAAAAABfm5Q", "name": "posters_22_33_MACcZtzkXaE.png", "path_lower": "/graduate studies/harvard/ac299r independent research/canva_scraping2_clean/posters/png_clean/posters_22_33_maccztzkxae.png", "link_permissions": {"resolved_visibility": {".tag": "public"}, "requested_visibility": {".tag": "public"}, "can_revoke": true, "visibility_policies": [{"policy": {".tag": "public"}, "resolved_policy": {".tag": "public"}, "allowed": true}, {"policy": {".tag": "team_only"}, "resolved_policy": {".tag": "team_only"}, "allowed": false, "disallowed_reason": {".tag": "user_not_on_team"}}, {"policy": {".tag": "password"}, "resolved_policy": {".tag": "password"}, "allowed": true}], "can_set_expiry": true, "can_remove_expiry": true, "allow_download": true, "can_allow_download": true, "can_disallow_download": false, "allow_comments": true, "team_restricts_comments": false}, "preview_type": "photo", "client_modified": "2019-01-30T18:13:54Z", "server_modified": "2019-02-13T23:57:00Z", "rev": "e46f01185b318", "size": 61194}
# Adding dropbox link to fold: https://www.dropbox.com/s/ec4pxysnbsxlsqw/posters_22_33_MACcZtzkXaE.png?raw=1
# chosen class: posters
# Trying to get dropbox link for posters_45_34_MACWevYW5Uo.png
