# %% [markdown]
# # Notebook to generate fold text files for the mturk task
#
# This notebook generates fold.txt files for each element in the canva_scarping2 dataset.
#
# Each fold.txt will contain 5-10 image names from the canva_scraping2 dataset. The image names will be links to Dropbox, as the canva_scraping2 dataset is hosted there.
#
# Folds can be built with a mix of multiple classes in each one of them, as to avoid having only book-covers or web-ads in each fold.
#
# Example structure of a fold.txt file:
#
# https://www.dropbox.com/s/gp9snrmlc54d3vo/certificates_1_18_MACS_ooy31s.png?raw=1
# https://www.dropbox.com/s/c32nwr8y37sw3or/certificates_1_10_MACTFpwVtmk.png?raw=1
#
# .
# .
# .
# .

# %%
# Imports
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json

# %%
# Constants
USE_FULL_DATASET = True
CLASSES_TO_USE = None
WITH_TEXT = True
FILES_PER_FOLD = 10
DATASET_PATH = '../canva_scraping2_clean'
FOLD_OUTPUT_DIR = './files'

# %% [markdown]
# ## Dataset stats

# %%
# Get statistics on canva_scraping2

# Get folder names
canva_scraping2_folders = [f for f in os.listdir(DATASET_PATH) if '_' not in f and '.' not in f and os.path.isdir(os.path.join(DATASET_PATH,f))]
print('Data folders in canva_scraping2:', canva_scraping2_folders)

num_elems_in_full_dataset = 0

SUBFOLDER = 'png_clean'

# Get number of elements in folders
for fol in canva_scraping2_folders:
    num_elems = len([p for p in os.listdir(os.path.join(DATASET_PATH, fol, 'png_clean')) if p.endswith('png')])
    print('Number of elements in folder %s: %d' % (fol, num_elems))
    num_elems_in_full_dataset += num_elems
    
print('Num elems in full dataset:', num_elems_in_full_dataset)
# Out:
# Data folders in canva_scraping2: ['book-covers', 'cd-covers', 'certificates', 'coupons', 'cvs', 'infographics', 'magazine-covers', 'posters', 'social-graphics', 'web-ads']
# Number of elements in folder book-covers: 363
# Number of elements in folder cd-covers: 28
# Number of elements in folder certificates: 216
# Number of elements in folder coupons: 175
# Number of elements in folder cvs: 123
# Number of elements in folder infographics: 148
# Number of elements in folder magazine-covers: 37
# Number of elements in folder posters: 1677
# Number of elements in folder social-graphics: 1123
# Number of elements in folder web-ads: 212
# Num elems in full dataset: 4102

# %% [markdown]
# ## Generate fold files

# %%
## Helper functions
def get_all_design_names(data_path, classes_to_use, subfolder='png'):    
    names_dict = {}
    
    for cl in classes_to_use:
        names_dict[cl] = []
    
    
    for cl in classes_to_use: 
        names_dict[cl] = [p for p in os.listdir(os.path.join(data_path, cl, subfolder)) if p.endswith('png')]
        
    return names_dict

## Generate fold files
def generate_fold_files(data_path, output_dir, classes_to_use = None, 
                        files_per_fold = 10, mix_classes = True, 
                        files_to_generate = 2, fold_prefix='fold', verbose = True, subfolder='png'):
    
    if not classes_to_use:
        classes_to_use = [f for f in os.listdir(DATASET_PATH) if '_' not in f and '.' not in f and os.path.isdir(os.path.join(DATASET_PATH,f))]

    
    num_folds_generated = 0
    unused_design_names = get_all_design_names(data_path, classes_to_use, subfolder=subfolder)
    
    while unused_design_names and num_folds_generated<files_to_generate:
        fold_txt_name = fold_prefix+str(num_folds_generated)+'.txt'
        fold_path = os.path.join(output_dir, fold_txt_name)
        
        generate_one_fold_file(fold_path, unused_design_names, files_per_fold, subfolder=subfolder)
        
        num_folds_generated +=1
        
        if verbose:
            print('Fold %s generated. %d files generated so far.' % (fold_txt_name, num_folds_generated))
        
    print('Done.')    
        
            
def generate_one_fold_file(fold_path, unused_design_names, files_per_fold, verbose =1, subfolder='png'):
    
    with open(fold_path, 'w+') as f:
        for _ in range(files_per_fold):
            if unused_design_names:
                # Sample a class
                cl = np.random.choice(list(unused_design_names.keys()))
                if verbose: print('chosen class:', cl)

                # Get a design name from that class
                design = np.random.choice(unused_design_names[cl])
                link = get_dropbox_link(design, cl, subfolder=subfolder)
                if verbose: print('Adding dropbox link to fold:', link)

                # Add to fold
                f.write(link+'\n')

                # Remove that design from the list of usable designs
                unused_design_names[cl].remove(design)
                if not unused_design_names[cl]:
                    del unused_design_names[cl]
            
    return unused_design_names


def get_dropbox_link(design, cl, subfolder='png'):
#     print(design)

    
    url = "https://api.dropboxapi.com/2/sharing/create_shared_link_with_settings"

    headers = {
        "Authorization": "Bearer -EVBtUP70JYAAAAAAACNue90xxn9wbCjB4RAZoE8Ys1buD7eEu0GRzbhD9XQqM9O",
        "Content-Type": "application/json"
    }

    data = {
        "path": "/Graduate Studies/Harvard/AC299r Independent Research/canva_scraping2_clean/"+cl+"/"+subfolder+"/"+design
    }

    r = requests.post(url, headers=headers, data=json.dumps(data))    
#     print(r.json())
    link = r.json()['url'][:-4]+'raw=1'
    return link


def dropbox_links_to_file_loc(dropbox_links, mid_folder='png'):
    file_locs = []
    for d in dropbox_links:
        name = d.split('/')[-1].split('?')[0]
        cl = name.split('_')[0]
        
        file_locs.append(os.path.join(cl, mid_folder, name))
        
    return file_locs

# %%
DATASET_PATH = '../canva_scraping2_clean'

generate_fold_files(data_path=DATASET_PATH, 
                    output_dir=FOLD_OUTPUT_DIR, 
                    classes_to_use=['posters'], #all classes will be used
                    files_per_fold = 10, 
                    mix_classes=True, 
                    files_to_generate=15,
                   fold_prefix = 'fold_poster_clean',
                   subfolder = 'png_clean')
# Out:
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/j6z62fmksoumafe/posters_12_6_MACRU1E_bXs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/h2wf7enac7kfgp8/posters_4_29_MACQe_TzKos.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/frm323x02dgxxyw/posters_1_22_MACBfIVRmbA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/hbvwx4z3o2gwx33/posters_26_30_MACYc4-LMD8.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/v90lwvazpmo3re3/posters_64_7_MACQk8cwMpE.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/zgjc97mlp3lin38/posters_61_26_MACcZebKYqM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/qt0emd61fagjm4y/posters_66_27_MACZMTxpiIY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/b2qnsnj40tazomp/posters_41_6_MACPSZYj4ok.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/103cfvk8xlxesyp/posters_42_5_MACagz-KmgY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/cay6laanyq4clp0/posters_2_6_MAB5Vxrk21s.png?raw=1
# Fold fold_poster_clean0.txt generated. 1 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/fc1aujs180z1pjp/posters_64_9_MACX5Vu_wHk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ymiapukhpejr52p/posters_15_17_MACTlXQBdEY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/0b0nf98dtsc5g1m/posters_45_27_MACZlv2w7v0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/9pnh65x63kx0rfg/posters_63_24_MACPSKNtK6k.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/r45i60s515zpov9/posters_40_4_MACayg8szVg.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/co2srkdzxfjk0qd/posters_10_21_MACAl3rSDKA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/i8e7p5u6eio2ef5/posters_9_17_MABu0Wl5Jmo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/uffmncaxh9s8uip/posters_19_32_MACY3FKRqm0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ee0s68qjbd623kx/posters_11_12_MACVkQI8EgY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/xq7pj7krtptq0n0/posters_19_26_MACa0KrCc1w.png?raw=1
# Fold fold_poster_clean1.txt generated. 2 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/aoe9as14xqbrjd3/posters_51_28_MACW28xvdc4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/q31owtsf3a4omft/posters_47_12_MACXDWBx4LU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/cejkfsyhgh8l46r/posters_13_9_MACY3KGd0XQ.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/v161y4lfrvp72fo/posters_64_26_MACVpmd7SFY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/bul28um4v27ydp6/posters_1_2_MACE2XZxHHs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/h6jatgtdn5co9nu/posters_41_23_MACTNHCCEJM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/13r4jj3eonv1t4r/posters_60_6_MACU9xHHQUk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/rpfxg1obfq0rwxc/posters_64_14_MACV_4Din64.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ygls0491wnji3hs/posters_55_22_MACYc57J_fo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/2vb1po5qkq1x0kf/posters_34_23_MACXtrg56G0.png?raw=1
# Fold fold_poster_clean2.txt generated. 3 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/rqagatocrrmsz4k/posters_50_28_MACPRdgq9q8.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/jy4qzbav41oofcw/posters_14_7_MACX5YdaRco.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/c91j2hn3sxnkljv/posters_20_20_MACW4CQ7s_w.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/1dih54n5oukx04i/posters_58_6_MACYYuqzqfg.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/stbj5h13ftmul0d/posters_45_0_MACTlhUKbMo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/34pbfom1m621qiw/posters_53_28_MACPqE93VfI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/uz4jwmvzs9ayj98/posters_34_12_MAB5XCgb0Vc.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/9gd0vmc8bqat08i/posters_2_14_MAB4BoqJzoQ.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ch42tgwgukstgjo/posters_48_27_MACZIkniuV4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/v19rlzabayj631s/posters_27_8_MACVpdrEz3g.png?raw=1
# Fold fold_poster_clean3.txt generated. 4 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/c26fo3hzew3l4wa/posters_47_6_MACOngxdDvI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/z2f37jh6hycsl16/posters_39_34_MACW9ulCU0w.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/52qf89f3h349llx/posters_53_33_MACXDMQaCVI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/fh77rvc5v6y5f9t/posters_6_16_MACHeSByBVM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/8d5o2fary6dwjh0/posters_60_1_MACbE4X7OPo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/vfg90wzlzxl45wf/posters_42_2_MAB-rxf1q98.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/afupedygrsb3gn3/posters_66_10_MACWN81X3Us.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/yfh21ul6g2fpse3/posters_62_18_MACffX0Ys8U.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/kqx7o3ecaehv2ak/posters_36_1_MACa4Y1sZHQ.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/uzlrz2jt4np64cs/posters_32_32_MACa-3-AbCA.png?raw=1
# Fold fold_poster_clean4.txt generated. 5 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/5xaiae1yspnokje/posters_56_5_MAB-sI7ZeJ0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/zt33h85no0lvryb/posters_61_13_MAB9XYDdkq4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/aj9732azacl9vwe/posters_16_13_MACRWL7SQXU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ua02qj4098nk8ub/posters_4_34_MACYdhc23vY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/3ys1lquiymfob2x/posters_13_22_MACUh95Je44.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ui4q5qjzhx5sb7f/posters_7_12_MAB5XK6P-Qw.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/9g1afn99g3g562j/posters_36_19_MACU53BjRfs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/khtfmw4pq6tob54/posters_10_24_MACVRicsIu0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/mti1g594n03gth1/posters_21_11_MACWSSTFmng.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ru6dj0ojdw5x2hz/posters_47_4_MACU4rB34f0.png?raw=1
# Fold fold_poster_clean5.txt generated. 6 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/s4tt0en3n9y59d8/posters_32_33_MACZwVk_zTI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ckzkus170rmgb74/posters_5_23_MACgO79Dj4A.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/21uij23pwy03wno/posters_34_17_MAB-sAOMW2g.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/82vff0mzuf24qis/posters_56_31_MACY7obhIZ0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/9k8hxa99bdft4y6/posters_58_19_MACcwr25jGc.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/t4gu3768ywyruvk/posters_14_5_MACUm57_bD0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/dbsd40rj8m694l9/posters_5_31_MACXn4nJ8hA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/v1ylwgv4jzu6vw4/posters_11_13_MACRm3UNXjw.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/hi43r2lmiry43y0/posters_21_1_MACRWCD7NFU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/shibv24a5t4lep6/posters_55_3_MACaypZtEtY.png?raw=1
# Fold fold_poster_clean6.txt generated. 7 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/pirs7gfwp0xxuqq/posters_34_4_MACag8rZbYI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/8nurmyft00nxa2y/posters_28_24_MACcwkGp0EA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/wiuecdisio88n2a/posters_12_17_MACdCgZuufM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/gp6yeh3pqt95c4l/posters_45_8_MACUhczjF_E.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/4hl93v285qraw69/posters_51_24_MACUg7S_CVc.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/nox1ndc6e43l8hn/posters_34_18_MACW-OjUwcg.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/1xi4389wmd6v1ra/posters_6_9_MACBUvJh4Ck.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/es19blqokuo78wg/posters_16_24_MACYXc3j_rs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/1ccaqpzywdzirfc/posters_66_26_MAB-lfXry6A.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/remflq1a1ohs27f/posters_7_8_MAB4NYJXYtc.png?raw=1
# Fold fold_poster_clean7.txt generated. 8 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/0vqk5zyvfmwxmco/posters_9_32_MACNwmEM4Qc.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/mqy0qiflizq0rgs/posters_44_11_MACS8o8VAbo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/di41gmqgjobu8sn/posters_25_2_MACcZr8_vZE.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/q827zf6kifbju4y/posters_50_24_MACWk4o-CDw.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/4klicxvfxllda0x/posters_55_23_MACXJP22KLo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/w0ds6d6ums1rizm/posters_18_31_MACRm4kZZx0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/wm3wf1afdqc5ble/posters_40_12_MACYdssrFvA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/pjnfr6w0a512n4q/posters_26_5_MACSXU_Cm7w.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/pyh1wzzj7boc3s9/posters_25_14_MACVE4mDcNM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/wdcrgl5istcc0uj/posters_57_7_MACcZuWXvek.png?raw=1
# Fold fold_poster_clean8.txt generated. 9 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/tqlllv3etgj1xe7/posters_4_25_MAB9YWG9vg4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/0qnidtsc8kk90bj/posters_25_20_MACU4opcDbs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/i0n8dbbrhb1xqol/posters_15_1_MACCiQpudpQ.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/002xvl7tmibyenh/posters_40_25_MACfevX1dsU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/w6a74ij47ajto9w/posters_34_8_MACcScaVSTU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/zb16t9k1o8u2paq/posters_49_6_MACUVdqnSvo.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/9mtyo4xk4r1o3n0/posters_57_6_MAB9XK8ITlg.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/zhoag09o9636dln/posters_10_16_MABy81Hy9Vk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/v4rx3oy1ox7j33h/posters_26_4_MACTrUn7fUk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/20mg8w938th98e4/posters_55_15_MACV10VM8cA.png?raw=1
# Fold fold_poster_clean9.txt generated. 10 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/j0rk0bf9jufx778/posters_50_2_MACY7mg6CS0.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/gvcvs90irahef1v/posters_3_10_MACU4xsYlJI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/8i6mud5s5vfir9m/posters_2_28_MAB9dfLl1Uk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/qqvtzdcy2gbqogp/posters_61_11_MACU9-6gNQ8.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/b3vgtnusnt0wvl2/posters_43_7_MACVv6pxPDk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/aqzah736zi3uajf/posters_25_0_MACcZP_LW3M.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/yretpsrxsdggav2/posters_65_7_MACXEPnyvpk.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/lse09wos4e2nezn/posters_44_2_MACU-aE4qrs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/odymgkk5gz8hkda/posters_21_21_MACUouPy7EM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/in5fyhtr5xvazof/posters_19_29_MACfekBOHDs.png?raw=1
# Fold fold_poster_clean10.txt generated. 11 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/04os28zf5zak5dr/posters_28_1_MACW8_LyRB8.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ifcmyjcn9m6le62/posters_44_30_MACbF-94iiw.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/891gulsg5a95cjj/posters_30_10_MACXnwP6y4o.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/n9s0l5ho7y2nei8/posters_51_7_MACPolxPScU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/7ybbtb6u9hiat4a/posters_3_20_MABK7UbQyP4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/f4qmeabi6eu853f/posters_7_7_MACF-qSV5ik.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ru0ueot0ml0cosk/posters_38_6_MACVouVp-KA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/et7114rmiwjmy3w/posters_6_22_MACZ14XCRBY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/44qc9kppmzpahtz/posters_29_32_MACU5AZgr3Y.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/63agwp1txsz34z1/posters_58_22_MACQlNHYiXU.png?raw=1
# Fold fold_poster_clean11.txt generated. 12 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/qrguaraig3gu8mx/posters_49_20_MACU36GkboA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/eoqq8131wmzdvux/posters_58_12_MACWZfs-JzU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/60hycvppswk3m7v/posters_48_4_MACUiLWjkg8.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/cgc0l5mh92ty48a/posters_65_26_MACU4FJas40.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/gi4ub6lie5dmxm2/posters_37_3_MAB4Mio_VAA.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/bg1lq0iq8yjueu5/posters_53_3_MACU6BnklXY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/8j6fdx0xht78eqi/posters_30_32_MACS7A7PR8g.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/dz1rsy4pstiqv7z/posters_36_23_MACPpr8IzCY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/1wvejrsfxfbdkso/posters_15_30_MACU0kipKZY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/uadts6oc4c0t0yj/posters_38_1_MACVF5p5Sjs.png?raw=1
# Fold fold_poster_clean12.txt generated. 13 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/5gakcgrelddhj36/posters_58_9_MACZF3Y0rEY.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/t1jtazcf9egqb8p/posters_47_3_MACdCgJjD4g.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/yu2w8ejekm6u0tr/posters_12_13_MACQmRclPFU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/hkn4yitoaylicdq/posters_21_9_MACVo9u7-jM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/buccixuw19gsvas/posters_13_11_MACVpKjuRkU.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/d31hjts2wdu4xzi/posters_38_7_MACUm3OVQaw.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/vfivxi6lqy34bos/posters_17_26_MACSXT6rw8c.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/4egd7h2s9v2ytiv/posters_53_1_MACay45zz2Q.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/mdpl827jdn3tuig/posters_22_21_MACU5Uco7z4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/h1x0d5ltvfb6d9z/posters_21_18_MACa_w559zM.png?raw=1
# Fold fold_poster_clean13.txt generated. 14 files generated so far.
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/jkhcad9x5so2eyz/posters_38_18_MACU_GDihFQ.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/sbyb6or34t8d8kj/posters_56_19_MACX5A0tC0M.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/slr9lwuczxxaz50/posters_3_11_MAB9Yacw7Ec.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/0yj39skq9eql6ep/posters_49_29_MACZksZQaOI.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/69pnmgw59ow2044/posters_59_29_MACWTuH5wq4.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/b5cllwdl6amwmqz/posters_35_2_MACWf14dU68.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/x0ej0j3wv476v92/posters_55_5_MACXDXXofBM.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/o05wb30tvpyedvg/posters_22_1_MAB-x029W7A.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/kqly3u1k1d7qbid/posters_31_8_MACPonk2uhs.png?raw=1
# chosen class: posters
# Adding dropbox link to fold: https://www.dropbox.com/s/ltp3325kv7v04fc/posters_6_5_MACiarCUPH8.png?raw=1
# Fold fold_poster_clean14.txt generated. 15 files generated so far.
# Done.

# %%
print(r.json()['links'][0]['url'])
# Out:
# https://www.dropbox.com/s/xlf8gfkoijbyhf8/infographics_1_0_MAB1w4Nre2U.png?dl=0
